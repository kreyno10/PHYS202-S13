# %% [markdown]
# Example
# -

# %%
import numpy.random
#print 5 uniformly distrib numbers between 0 and 1
print numpy.random.random(5)
#print another 5, difeferent
print numpy.random.random(5)
# Out:
# [ 0.33748001  0.42948435  0.84272873  0.51541399  0.81572964]
# [ 0.15819932  0.95526164  0.57006519  0.96448809  0.29765673]

# %%
#set the seed
numpy.random.seed(4242)
#print r rando numbers with this seed
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#resore seed to original
numpy.random.seed(None)
#print 5 numbers using random seed
print "Using seed =None"
print numpy.random.random(5)
# Out:
# Using seed =None
# [ 0.80005756  0.98597153  0.46915883  0.60694871  0.94152662]

# %%
#reset seed to 4242
numpy.random.seed(4242)
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#reset the seed
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z, 100, normed=True)
plot([0,1.],[1.,1.],'r-',lw=3)
xlabel("x",fontsize=20)
ylabel("sample prob",fontsize=20)
show()

# %% [markdown]
# CDF Example
# --

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2
F = lambda x: (cos(0)-cos(x))/2

plot(x,f(x),label="True Distribution",lw=3)
plot(x, F(x),label="Cumulative function",lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N = 10000
#N random numbers between 0 and 1
z = numpy.random.random_sample(N);
#inverse CDF
Finv = lambda z: arccos(cos(0) - 2*z)
#sampled x values
xsamples = Finv(z);
#how do they compare to original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label="True distribution",lw=3,color="red")
xlim(0,pi)
ylim(0,0.7)
legend(loc=0)
show()

# %% [markdown]
# exercise 1
# -

# %%
x = arange(0.,1000+0.01,0.01)
l = 1
f = lambda x: l*exp(-l*x)
F = lambda x: -exp(-l*x)

plot(x, f(x),label="True Distribution",lw=3)
plot(x, F(x),label="Cumulative Function",lw=3)

xlim(0,5.)
ylim(-2,2.)
legend(loc=0)
show()

# %%
#number of samples
N = 10000
#N random numbers
z = numpy.random.random_sample(N);
#inverse CDF
Finv = lambda z: -log(-l*z)
#sampled x values
xsamples = Finv(z);
#compare to original
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="true distribution",lw=3,color='red')
xlim(0,5.)
ylim(-5,5.)
logend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-49a62d8597be> in <module>()
#       8 xsamples = Finv(z);
#       9 #compare to original
# ---> 10 hist(xsamples,50,normed=True,label="Sampled Distribution")
#      11 plot(x,f(x),label="true distribution",lw=3,color='red')
#      12 xlim(0,5.)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, hold, **kwargs)
#    2330         ax.hold(hold)
#    2331     try:
# -> 2332         ret = ax.hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    2333         draw_if_interactive()
#    2334     finally:
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/matplotlib/axes.py in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, **kwargs)
#    7658             # this will automatically overwrite bins,
#    7659             # so that each histogram uses the same bins
# -> 7660             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7661             if normed:
#    7662                 db = np.diff(bins)
#
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/numpy/lib/function_base.py in histogram(a, bins, range, normed, weights, density)
#     156         if (mn > mx):
#     157             raise AttributeError(
# --> 158                 'max must be larger than min in range parameter.')
#     159
#     160     if not iterable(bins):
#
# AttributeError: max must be larger than min in range parameter.
# -c:6: RuntimeWarning: invalid value encountered in log

# %%
x = arange(0.,1000+0.001,0.01)
l = 1
f = lambda x: l*exp(-l*x)
distribution = []
for i in x:
    distribution.append(f(i))
sum_dist = np.cumsum(distribution)
normal = sum_dist/sum(distribution)
z = random.uniform(0,1)
print z
index = np.searchsorted(normal, z)
print index
value = normal[index]
print value
# Out:
# 0.751670143329
# 139
# 0.753403036058

# %%
plot(x, f(x),label="True Distribution",lw=3)
plot(x, normal,label="numerically determined CDF",lw=3)
xlim(0,5.)
ylim(-2,2.)
legend(loc=0)
show()
