# %% [markdown]
# Example
# -

# %%
import numpy.random
#print 5 uniformly distrib numbers between 0 and 1
print numpy.random.random(5)
#print another 5, difeferent
print numpy.random.random(5)
# Out:
# [ 0.20219667  0.77924173  0.49086676  0.6142053   0.67338736]
# [ 0.19646908  0.3928033   0.21662768  0.2150411   0.04742534]

# %%
#set the seed
numpy.random.seed(4242)
#print r rando numbers with this seed
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#resore seed to original
numpy.random.seed(None)
#print 5 numbers using random seed
print "Using seed =None"
print numpy.random.random(5)
# Out:
# Using seed =None
# [ 0.60107312  0.2647702   0.18605879  0.82042793  0.07292287]

# %%
#reset seed to 4242
numpy.random.seed(4242)
print "Using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# Using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#reset the seed
numpy.random.seed(None)
z = numpy.random.random(100000)
hist(z, 100, normed=True)
plot([0,1.],[1.,1.],'r-',lw=3)
xlabel("x",fontsize=20)
ylabel("sample prob",fontsize=20)
show()

# %% [markdown]
# CDF Example
# --

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2
F = lambda x: (cos(0)-cos(x))/2

plot(x,f(x),label="True Distribution",lw=3)
plot(x, F(x),label="Cumulative function",lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %%
#number of samples
N = 10000
#N random numbers between 0 and 1
z = numpy.random.random_sample(N);
#inverse CDF
Finv = lambda z: arccos(cos(0) - 2*z)
#sampled x values
xsamples = Finv(z);
#how do they compare to original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label="True distribution",lw=3,color="red")
xlim(0,pi)
ylim(0,0.7)
legend(loc=0)
show()

# %% [markdown]
# exercise 1
# -

# %%
x = arange(0.,1000+0.01,0.01)
l = 1
f = lambda x: l*exp(-l*x)
F = lambda x: -exp(-l*x)

plot(x, f(x),label="True Distribution",lw=3)
plot(x, F(x),label="Cumulative Function",lw=3)

xlim(0,5.)
ylim(-2,2.)
legend(loc=0)
show()

# %%
#number of samples
N = 10000
#N random numbers
z = numpy.random.random_sample(N);
#inverse CDF
Finv = lambda z: -log(-l*z)
#sampled x values
xsamples = Finv(z);
#compare to original
hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="true distribution",lw=3,color='red')
xlim(0,5.)
ylim(-5,5.)
logend(loc=0)
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-49a62d8597be> in <module>()
#       8 xsamples = Finv(z);
#       9 #compare to original
# ---> 10 hist(xsamples,50,normed=True,label="Sampled Distribution")
#      11 plot(x,f(x),label="true distribution",lw=3,color='red')
#      12 xlim(0,5.)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2670                       histtype=histtype, align=align, orientation=orientation,
#    2671                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2672                       stacked=stacked, **kwargs)
#    2673         draw_if_interactive()
#    2674     finally:
#
# ...

# %%
x = arange(0.,1000+0.001,0.01)
l = 1
f = lambda x: l*exp(-l*x)
distribution = []
for i in x:
    distribution.append(f(i))
sum_dist = np.cumsum(distribution)
normal = sum_dist/sum(distribution)
z = random.uniform(0,1)
print z
index = np.searchsorted(normal, z)
print index
value = normal[index]
print value
# Out:
# 0.77349997842
# 148
# 0.774627344461

# %%
plot(x, f(x),label="True Distribution",lw=3)
plot(x, normal,label="numerically determined CDF",lw=3)
xlim(0,5.)
ylim(-2,2.)
legend(loc=0)
show()

# %%
def distribute1D(x, prob, N):
    sum_dist = np.cumsum(distribution)
    normal = sum_dist/sum(distribution)
    z = []
    for i in range(N):
        z.append(random.uniform(0,1))
    index = []
    for i in range(N):
        index.append(np.searchsorted(normal, z[i]))
    value = []
    for i in range(N):
        value.append(normal[index[i]])
    return value

# %%
x = arange(0.,1000+0.001,0.01)
l = 1
f = lambda x: l*exp(-l*x)
distribution = []
for i in x:
    distribution.append(f(i))
test = distribute1D(x, distribution, 10)
print test
# Out:
# [0.91625677440780806, 0.16472978858872883, 0.67372020537696375, 0.56395071367846727, 0.51324774404003093, 0.43447456130046513, 0.44010163343460024, 0.31613859078764578, 0.48314866550830327, 0.78346433268399673]

# %% [markdown]
# Exercise 3
# -

# %%
d = 15 * 10**-6
a = 10*10**-6
L = 1
lamb = 632.8*1**-9
x = arange(-0.2, 0.25, 0.05)
f = lambda x: ((sin(a*pi*x/(lamb*L))/(pi*x*a/(lamb*L))))**2 * ((cos(2*pi*d*x/(lamb*L)))**2)
prob_dist = []
for n in x:
    prob_dist.append(f(i))
    
sum_prob_dist = np.cumsum(prob_dist)
norm_prob_dist = sum_dist/sum(prob_dist)
#plot(x,prob_dist)

photons = distribute1D(x, prob_dist, 10000)
plot(x, photons)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-4624d7ac2200> in <module>()
#      14
#      15 photons = distribute1D(x, prob_dist, 10000)
# ---> 16 plot(x, photons)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2830         ax.hold(hold)
#    2831     try:
# -> 2832         ret = ax.plot(*args, **kwargs)
#    2833         draw_if_interactive()
#    2834     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3994         lines = []
#    3995
# -> 3996         for line in self._get_lines(*args, **kwargs):
#    3997             self.add_line(line)
#    3998             lines.append(line)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes.pyc in _grab_next_args(self, *args, **kwargs)
#     328                 return
# ...

# %%
x = arange(-0.2, 0.25, 0.05)
plot(x, f(x)*max(photons), label="True Distribution")
hist(photons,50,normed=True,label="Sampled Distribution")
legend(loc=0)
show()
