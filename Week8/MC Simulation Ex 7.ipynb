# %% [markdown]
# 2)
# -

# %%
x = arange(0,30.1, 0.1)
a = 1.5
B = 6
f = lambda x: a*B**(-a)*x**(a-1)*exp(-(x/B)**a)
F = lambda x: 1 - exp(-(x/B)**a)
#number of samples
N = 10000
#N random numbers
z = numpy.random.random_sample(N);
#inverse CDF
Finv = lambda z: B*(-log(1-z))**(1/a)
#sampled x values
xsamples = Finv(z)

#compare to original
plot(x,f(x),label="true distribution",lw=3)
plot(x, F(x), label="CDF", lw =3)
hist(xsamples,50,normed=True,label="Sampled Distribution")

legend(loc=0)
show()

# %% [markdown]
# 3)
# -

# %%
f = lambda x: 60*x**3 * (1 - x)**2
x = arange(0, 1.01, .01)
myplot = plot(x,f(x),lw=3)
show()

# %%
xmin = 0.01
xmax = .99
subx = x[logical_and((x> xmin), (x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0. 

myplot = plot(x, f(x), lw=3)

plot([xmin,xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x, f(x), lw=3)

plot(samples_x[1:200],samples_y[1:200],'.')

plot([xmin,xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
newmask = (samples_y < f(samples_x))
sum(newmask)
myplot= plot(x, f(x), lw=3)

plot(samples_x[1:200],samples_y[1:200],'.')

plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')#these red dots are the samples

plot([xmin,xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax,xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
f = lambda x: 60*x**3 * (1 - x)**2
F = lambda x: 10*x**6 - 24*x**5 + 15*x**4
x = arange(0, 1.01, .01)
plot(x,f(x),lw=3, label="True Distribution")
plot(x, F(x), lw = 3, label="CDF")
hist(samples_x[newmask[:200]], 50, normed=True, label="Sample Distribution")
legend(loc=0)
xlim(0, 1)
ylim(-2, 3)
show()
