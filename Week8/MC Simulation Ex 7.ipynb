# %% [markdown]
# 2)
# -

# %%
x = arange(0,10, 0.1)
a = 1.5
B = 6
f = lambda x: a*B**(-a)*x**(a-1)*exp(-(x/B)**a)
F = lambda x: B**(-a)*exp(-(x/B)**a)
Finv = lambda x: -B*(log(x/(B**-a))**(-1/a))
#number of samples
N = 10000
#N random numbers
z = numpy.random.random_sample(N);
#inverse CDF
Finv2 = lambda z: -B*(log(z/(B**-a))**(-1/a))
#sampled x values
xsamples = Finv2(z)
#compare to original
#hist(xsamples,50,normed=True,label="Sampled Distribution")
plot(x,f(x),label="true distribution",lw=3,color='red')
plot(x, F(x), label="CDF", lw =3, color="green")
#xlim(0,5.)
#ylim(-5,5.)
legend(loc=0)
show()

# %%
math.inverse?
# Out:
# Object `math.inverse` not found.
