# %% [markdown]
# Example 1
# ==

# %%
l = w = 4
r = 1.375
Nin = 15
N = 40
Aboard = l* w
Aexact = pi*r**2
Acirc = (Nin/float(N))*Aboard
print "Aboard=",Aboard
print"Aexact=",Aexact
print "Acirc=", Acirc
print "Error=", (100.*(Acirc-Aexact)/Aexact),"%"
# Out:
# Aboard= 16
# Aexact= 5.93957361069
# Acirc= 6.0
# Error= 1.01735230957 %

# %% [markdown]
# Example 1
# =

# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x, f(x), lw=3)
ylabel(r'${1/2} + \sin{x}$', fontsize=20)
xlabel(r'$x$',fontsize=20)
xlim(0.,15.)
show()

# %%
xmin = 1.7
xmax = 12.4

subx = x[logical_and((x > xmin), (x < xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

myplot= plot(x,f(x),lw=3)
xlim(0.,15.)

plot([xmin, xmin], [ymin,ymax], color ='k', linestyle="--")
plot([xmax,xmax],[ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')
show()

# %%
N = 10000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x, f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200], '.')

plot([xmin, xmin], [ymin,ymax], color ='k', linestyle="--")
plot([xmax,xmax],[ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')
show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6181268

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot(samples_x[newmask[:200]],samples_y[newmask[:200]], 'r.')

plot([xmin, xmin], [ymin,ymax], color ='k', linestyle="--")
plot([xmax,xmax],[ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')
show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.5166011959

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact - I)/Iexact
print "I_exact ", Iexact
print "I_hitormiss =", I
print "Error on I =", Ierr, "%"
# Out:
# I_exact  26.5172145362
# I_hitormiss = 26.5166011959
# Error on I = 0.0023129891959 %

# %% [markdown]
# Exercise 1
# ==

# %%
f = lambda x: x**(0.5) + sin(x)
x = arange(0.,15.,0.001)
myplot = plot(x, f(x), lw=3)
ylabel(r'${1/2} + \sin{x}$', fontsize=20)
xlabel(r'$x$',fontsize=20)
xlim(0.,15.)
show()

# %%
N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x, f(x), lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200], '.')

plot([xmin, xmin], [ymin,ymax], color ='k', linestyle="--")
plot([xmax,xmax],[ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')
show()

# %%
newmask = (samples_y < f(samples_x))
sum(newmask)
# Out:
# 6165

# %%
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot(samples_x[newmask[:200]],samples_y[newmask[:200]], 'r.')

plot([xmin, xmin], [ymin,ymax], color ='k', linestyle="--")
plot([xmax,xmax],[ymin,ymax], color='k', linestyle='--')
plot([xmin,xmax], [ymax,ymax], color='k', linestyle='--')
show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.4468142091

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact - I)/Iexact
print "I_exact ", Iexact
print "I_hitormiss =", I
print "Error on I =", Ierr, "%"
# Out:
# I_exact  26.5172145362
# I_hitormiss = 26.4468142091
# Error on I = 0.265489148568 %

# %% [markdown]
# Exercise 2
# =

# %%
f = lambda x: x**(0.5) + sin(x)
N = 10000
a = 1.7
b = 12.4
x = arange(1.7,12.4,.001)
randx = (b -a) *random_sample(N)+a
In = (b - a)*average(f(randx))
print In
# Out:
# 26.4495923241

# %%
plot(x,f(x), label='original function')
av = average(f(x))
axhline(y = av, color = 'r', label = 'average')
legend(loc = 'upper left')
check = av * (b-a)
print "average value check = ",check
# Out:
# average value check =  26.516684482

# %%
percentError = 100*(Iexact - In)/Iexact
print percentError
# Out:
# 0.255012501515

# %% [markdown]
# Example 2
# ==

# %%
fxyz = lambda x,y,z:sqrt(x**2 + y**2 + z**2)
N = 1e6
L = 1.;W =1.;H = 1.
x = L*random_sample(N); y = W*random_sample(N); z = H*random_sample(N)
IntMC = (L*W*H/N)*sum(fxyz(x,y,z))

# %%
N = 10000
fsph = lambda r, phi: (cos(phi)/r**3)
phiMax = 2*pi; thetaMax = pi; rMax = 1;
phi = phiMax*random_sample(N);
theta = thetaMax*random_sample(N);
r = rMax*random_sample(N);
Integral_MC = (phiMax*thetaMax*rMax/N)*sum(fsph(r,phi)*r**2*sin(theta))

# %%
import sys
sys.path.insert(0, '/Network/Servers/cp-file-home.cp-calpoly.edu/studentHome$/user/kreyno10/PHYS202-S13/Week4')

from Electrostatics import *

sigma = 1*10**-6;
N = 1*10**6;
x0 = 2.
y0 = 3.;
xi = -1 + 2.001*random_sample(N);
yi = 0. + 2.001*random_sample(N);

Vi = pointPotential(x0, y0, sigma, xi, yi);

Vtot = (2.*2./N)*sum(Vi)

# %% [markdown]
# Exercise 3
# ==

# %%
import sys
sys.path.insert(0, '/Network/Servers/cp-file-home.cp-calpoly.edu/studentHome$/user/kreyno10/PHYS202-S13/Week4')

from Electrostatics import *

sigma = 2*10**-9;
N = 1*10**6;
x0 = 2.
y0 = 3.;
xi = 0 + .012*random_sample(N);
yi = 0. + 2*pi*random_sample(N);

Vi = pointPotential(x0, y0, sigma, xi, yi);

Vtot = (2.*2./N)*sum(Vi)
print Vtot
# Out:
# 11.3637554067
